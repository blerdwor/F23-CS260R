# %%
# !pip uninstall metadrive-simulator --yes

# Install MetaDrive, a lightweight driving simulator
# !pip install git+https://github.com/metadriverse/metadrive
# !git clone https://github.com/metadriverse/metadrive.git
# !cd metadrive
# !pip install -e .

# Test whether MetaDrive is properly installed. No error means the test is passed.
# !python -m metadrive.examples.profile_metadrive --num-steps 100
# Out:
# Found existing installation: metadrive-simulator 0.4.1.2
# Uninstalling metadrive-simulator-0.4.1.2:
#   Successfully uninstalled metadrive-simulator-0.4.1.2
# Cloning into 'metadrive'...
# Updating files:  20% (283/1391)
# Updating files:  21% (293/1391)
# Updating files:  22% (307/1391)
# Updating files:  23% (320/1391)
# Updating files:  24% (334/1391)
# Updating files:  25% (348/1391)
# Updating files:  26% (362/1391)
# Updating files:  27% (376/1391)
# Updating files:  28% (390/1391)
# Updating files:  29% (404/1391)
# Updating files:  30% (418/1391)
# Updating files:  31% (432/1391)
# Updating files:  32% (446/1391)
# Updating files:  33% (460/1391)
# Updating files:  34% (473/1391)
# Updating files:  35% (487/1391)
# Updating files:  36% (501/1391)
# Updating files:  37% (515/1391)
# Updating files:  38% (529/1391)
# Updating files:  39% (543/1391)
# Updating files:  40% (557/1391)
# Updating files:  41% (571/1391)
# Updating files:  42% (585/1391)
# Updating files:  42% (586/1391)
# Updating files:  43% (599/1391)
# Updating files:  44% (613/1391)
# Updating files:  45% (626/1391)
# Updating files:  46% (640/1391)
# Updating files:  47% (654/1391)
# Updating files:  48% (668/1391)
# Updating files:  49% (682/1391)
# Updating files:  50% (696/1391)
# Updating files:  51% (710/1391)
# Updating files:  52% (724/1391)
# Updating files:  53% (738/1391)
# Updating files:  54% (752/1391)
# Updating files:  55% (766/1391)
# Updating files:  56% (779/1391)
# Updating files:  57% (793/1391)
# Updating files:  58% (807/1391)
# Updating files:  59% (821/1391)
# Updating files:  60% (835/1391)
# Updating files:  61% (849/1391)
# Updating files:  62% (863/1391)
# Updating files:  62% (865/1391)
# Updating files:  63% (877/1391)
# Updating files:  64% (891/1391)
# Updating files:  65% (905/1391)
# Updating files:  66% (919/1391)
# Updating files:  67% (932/1391)
# Updating files:  68% (946/1391)
# Updating files:  69% (960/1391)
# Updating files:  70% (974/1391)
# Updating files:  71% (988/1391)
# Updating files:  72% (1002/1391)
# Updating files:  73% (1016/1391)
# Updating files:  74% (1030/1391)
# Updating files:  75% (1044/1391)
# Updating files:  76% (1058/1391)
# Updating files:  77% (1072/1391)
# Updating files:  78% (1085/1391)
# Updating files:  79% (1099/1391)
# Updating files:  80% (1113/1391)
# Updating files:  81% (1127/1391)
# Updating files:  82% (1141/1391)
# Updating files:  83% (1155/1391)
# Updating files:  84% (1169/1391)
# Updating files:  85% (1183/1391)
# Updating files:  86% (1197/1391)
# Updating files:  87% (1211/1391)
# Updating files:  88% (1225/1391)
# Updating files:  89% (1238/1391)
# Updating files:  90% (1252/1391)
# Updating files:  91% (1266/1391)
# Updating files:  92% (1280/1391)
# Updating files:  93% (1294/1391)
# Updating files:  94% (1308/1391)
# Updating files:  95% (1322/1391)
# Updating files:  96% (1336/1391)
# Updating files:  97% (1350/1391)
# Updating files:  98% (1364/1391)
# Updating files:  99% (1378/1391)
# Updating files: 100% (1391/1391)
# Updating files: 100% (1391/1391), done.
# Obtaining file:///C:/Users/blerd/Desktop/assignment4/agents/example_agent
# ERROR: file:///C:/Users/blerd/Desktop/assignment4/agents/example_agent does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# c:\Users\blerd\anaconda3\envs\cs260r\python.exe: Error while finding module specification for 'metadrive.examples.profile_metadrive' (ModuleNotFoundError: No module named 'metadrive.examples')

# %%
# Test whether MetaDrive is properly installed. No error means the test is passed.
# !python -m metadrive.examples.profile_metadrive --num-steps 100
