# %%
# !pip uninstall metadrive-simulator --yes
# !pip uninstall panda3d-simplepbr --yes

# Install MetaDrive, a lightweight driving simulator
# !pip install panda3d-simplepbr==0.10.0
# !pip install git+https://github.com/metadriverse/metadrive
# Out:
# WARNING: Skipping metadrive-simulator as it is not installed.
# WARNING: Skipping panda3d-simplepbr as it is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 MB 9.5 MB/s eta 0:00:0000:0100:01
# ...
#   Cloning https://github.com/metadriverse/metadrive to /private/var/folders/p5/0n80kpk16333nfcthvg_lg1w0000gq/T/pip-req-build-bjamwv4m
#   Running command git clone --filter=blob:none --quiet https://github.com/metadriverse/metadrive /private/var/folders/p5/0n80kpk16333nfcthvg_lg1w0000gq/T/pip-req-build-bjamwv4m
#   Resolved https://github.com/metadriverse/metadrive to commit 73187f6f2447f0cb2960db0d409bec02ee4e0f8c
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 9.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 38.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 9.2 MB/s eta 0:00:00
# ...

# %%
# Test whether MetaDrive is properly installed. No error means the test is passed.
# !python -m metadrive.examples.profile_metadrive --num-steps 100
# Out:
# Start to profile the efficiency of MetaDrive with 1000 maps and ~4 vehicles!
# [INFO] Environment: MetaDriveEnv
# [INFO] MetaDrive version: 0.4.1.2
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): None
# [WARNING] Assets folder doesn't exist. Begin to download assets... (base_engine.py:781)
# [INFO] Pull assets from https://github.com/metadriverse/metadrive/releases/download/MetaDrive-0.4.1.2/assets.zip to /Users/belle/anaconda3/envs/cs260r/lib/python3.11/site-packages/metadrive/assets.zip
# 100% |#########################################################################|
# [INFO] Successfully download assets, version: 0.4.1.2. MetaDrive version: 0.4.1.2
# [INFO] Known Pipes: CocoaGraphicsPipe
# [INFO] Start Scenario Index: 1010, Num Scenarios : 1000
# ...

# %%
# !pip install torch pandas scipy seaborn tabulate pyyaml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 25.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 36.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.9/168.9 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# %run ./train_ppo_in_singleagent_env.py \
--log-dir train_ppo_in_single_agent_env \
--pretrained-model-log-dir ./train_ppo_in_single_agent_env/ppo \
--pretrained-model-suffix iter55 \
--num-processes 10 \
--num-steps 4_000 \
--max-steps 10_000_000
# Out:
# [INFO] Environment: SingleAgentRacingEnv
# [INFO] MetaDrive version: 0.4.1.2
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 3000
# [WARNING] When reaching max steps, both 'terminate' and 'truncate will be True.Generally, only the `truncate` should be `True`. (base_env.py:399)
# Successfully loaded weights from /Users/belle/Desktop/F23-CS260R/train_ppo_in_single_agent_env/ppo/checkpoint-iter55.pkl!
# Successfully loaded pretrained model at ./train_ppo_in_single_agent_env/ppo with suffix iter55.
# Start training!
# [INFO] Environment: SingleAgentRacingEnv
# [INFO] MetaDrive version: 0.4.1.2
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 3000
# ...
