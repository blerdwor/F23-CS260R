# %%
# !pip uninstall metadrive-simulator --yes
# !pip uninstall panda3d-simplepbr --yes

# Install MetaDrive, a lightweight driving simulator
# !pip install panda3d-simplepbr==0.10.0
# !pip install git+https://github.com/metadriverse/metadrive
# Out:
# WARNING: Skipping metadrive-simulator as it is not installed.
# Found existing installation: panda3d-simplepbr 0.10
# Uninstalling panda3d-simplepbr-0.10:
#   Successfully uninstalled panda3d-simplepbr-0.10
# Collecting panda3d-simplepbr==0.10.0
#   Using cached panda3d_simplepbr-0.10-py3-none-any.whl (10 kB)
# Requirement already satisfied: panda3d>=1.10.8 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from panda3d-simplepbr==0.10.0) (1.10.13)
# Installing collected packages: panda3d-simplepbr
# Successfully installed panda3d-simplepbr-0.10
# Collecting git+https://github.com/metadriverse/metadrive
#   Cloning https://github.com/metadriverse/metadrive to c:\users\blerd\appdata\local\temp\pip-req-build-vm0pmg_4
#   Resolved https://github.com/metadriverse/metadrive to commit e001457656eddf3122682eb262fc8705d656a979
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (2.31.0)
# Requirement already satisfied: gymnasium<0.29,>=0.28 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (0.28.1)
# Requirement already satisfied: numpy<=1.24.2,>=1.21.6 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (1.24.2)
# Requirement already satisfied: matplotlib in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (3.8.2)
# Requirement already satisfied: pandas in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (2.1.3)
# Requirement already satisfied: pygame in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (2.5.2)
# Requirement already satisfied: tqdm in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (4.66.1)
# Requirement already satisfied: yapf in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (0.40.2)
# Requirement already satisfied: seaborn in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (0.13.0)
# Requirement already satisfied: progressbar in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (2.5)
# Requirement already satisfied: panda3d==1.10.13 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (1.10.13)
# Requirement already satisfied: panda3d-gltf==0.13 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (0.13)
# Requirement already satisfied: panda3d-simplepbr in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (0.10)
# Requirement already satisfied: pillow in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (10.1.0)
# Requirement already satisfied: pytest in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (7.4.3)
# Requirement already satisfied: opencv-python in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (4.8.1.78)
# Requirement already satisfied: lxml in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (4.9.3)
# Requirement already satisfied: scipy in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (1.11.4)
# Requirement already satisfied: psutil in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (5.9.0)
# Requirement already satisfied: geopandas in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (0.14.1)
# Requirement already satisfied: shapely in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (2.0.2)
# Requirement already satisfied: filelock in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (3.13.1)
# Requirement already satisfied: Pygments in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from metadrive-simulator==0.4.1.2) (2.17.2)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from gymnasium<0.29,>=0.28->metadrive-simulator==0.4.1.2) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from gymnasium<0.29,>=0.28->metadrive-simulator==0.4.1.2) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from gymnasium<0.29,>=0.28->metadrive-simulator==0.4.1.2) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from gymnasium<0.29,>=0.28->metadrive-simulator==0.4.1.2) (0.0.4)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from geopandas->metadrive-simulator==0.4.1.2) (1.9.5)
# Requirement already satisfied: packaging in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from geopandas->metadrive-simulator==0.4.1.2) (23.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from geopandas->metadrive-simulator==0.4.1.2) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pandas->metadrive-simulator==0.4.1.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pandas->metadrive-simulator==0.4.1.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pandas->metadrive-simulator==0.4.1.2) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib->metadrive-simulator==0.4.1.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib->metadrive-simulator==0.4.1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib->metadrive-simulator==0.4.1.2) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib->metadrive-simulator==0.4.1.2) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib->metadrive-simulator==0.4.1.2) (3.1.1)
# Requirement already satisfied: iniconfig in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pytest->metadrive-simulator==0.4.1.2) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pytest->metadrive-simulator==0.4.1.2) (1.3.0)
# Requirement already satisfied: colorama in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pytest->metadrive-simulator==0.4.1.2) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from requests->metadrive-simulator==0.4.1.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from requests->metadrive-simulator==0.4.1.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from requests->metadrive-simulator==0.4.1.2) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from requests->metadrive-simulator==0.4.1.2) (2023.11.17)
# Requirement already satisfied: importlib-metadata>=6.6.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from yapf->metadrive-simulator==0.4.1.2) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from yapf->metadrive-simulator==0.4.1.2) (4.1.0)
# Requirement already satisfied: tomli>=2.0.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from yapf->metadrive-simulator==0.4.1.2) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from fiona>=1.8.21->geopandas->metadrive-simulator==0.4.1.2) (23.1.0)
# Requirement already satisfied: click~=8.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from fiona>=1.8.21->geopandas->metadrive-simulator==0.4.1.2) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from fiona>=1.8.21->geopandas->metadrive-simulator==0.4.1.2) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from fiona>=1.8.21->geopandas->metadrive-simulator==0.4.1.2) (0.7.2)
# Requirement already satisfied: six in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from fiona>=1.8.21->geopandas->metadrive-simulator==0.4.1.2) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from fiona>=1.8.21->geopandas->metadrive-simulator==0.4.1.2) (68.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from importlib-metadata>=6.6.0->yapf->metadrive-simulator==0.4.1.2) (3.17.0)
# Building wheels for collected packages: metadrive-simulator
#   Building wheel for metadrive-simulator (setup.py): started
#   Building wheel for metadrive-simulator (setup.py): still running...
#   Building wheel for metadrive-simulator (setup.py): finished with status 'done'
#   Created wheel for metadrive-simulator: filename=metadrive_simulator-0.4.1.2-py3-none-any.whl size=54982401 sha256=f77bebe53f7f54019e20baf50c2e122636ea04dedb628e940b2e1b3e952f60af
#   Stored in directory: C:\Users\blerd\AppData\Local\Temp\pip-ephem-wheel-cache-npw3ldnv\wheels\2e\6b\5f\46cd593cd59e951e6c415250dbdd8bdce04c51239a9bce0adf
# Successfully built metadrive-simulator
# Installing collected packages: metadrive-simulator
# Successfully installed metadrive-simulator-0.4.1.2
#   Running command git clone --filter=blob:none --quiet https://github.com/metadriverse/metadrive 'C:\Users\blerd\AppData\Local\Temp\pip-req-build-vm0pmg_4'

# %%
# Test whether MetaDrive is properly installed. No error means the test is passed.
# !python -m metadrive.examples.profile_metadrive --num-steps 100
# Out:
# Start to profile the efficiency of MetaDrive with 1000 maps and ~4 vehicles!
# Finish 100/100 simulation steps. Time elapse: 0.6282. Average FPS: 413.5367, Average number of vehicles: 4.0000
# Total Time Elapse: 0.628, average FPS: 413.537, average number of vehicles: 4.000.
# [INFO] Environment: MetaDriveEnv
# [INFO] MetaDrive version: 0.4.1.2
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): None
# [INFO] Assets version: 0.4.1.2
# [INFO] Known Pipes: wglGraphicsPipe
# [INFO] Start Scenario Index: 1010, Num Scenarios : 1000
# [INFO] Episode ended! Scenario Index: 1397 Reason: crash vehicle

# %%
# !pip install pandas scipy seaborn tabulate pyyaml
# Out:
# Requirement already satisfied: pandas in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (2.1.3)
# Requirement already satisfied: scipy in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (1.11.4)
# Requirement already satisfied: seaborn in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (0.13.0)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting pyyaml
#   Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\blerd\anaconda3\envs\cs260r\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
# Installing collected packages: tabulate, pyyaml
# Successfully installed pyyaml-6.0.1 tabulate-0.9.0

# %%
# %run ./train_ppo_in_singleagent_env.py \
--log-dir train_ppo_in_single_agent_env \
--num-processes 10 \
--num-steps 4_000 \
--max-steps 10_000_000
# Out:
# [INFO] Environment: SingleAgentRacingEnv
# [INFO] MetaDrive version: 0.4.1.2
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 3000
# [WARNING] When reaching max steps, both 'terminate' and 'truncate will be True.Generally, only the `truncate` should be `True`. (base_env.py:399)
# No pretrained model is loaded. You will train the agent from scratch.
# Start training!
#   0%|          | 40000/10000000 [02:06<8:43:08, 317.31it/s]
#  ===== ppo Training Iteration 0 =====:
#   adv_mean: -12.2376127243042
#   crash_sidewalk_rate: 0.014633333333333333
#   crash_vehicle_rate: 0.0
#   entropy: 2.837973644488897
#   episode_length: 3000.0
#   episode_reward: -2399.4104066848754
#   frame_per_second: 227
#   grad_norm: 212.16181373810156
#   idle_rate: 0.0
#   iteration: 0
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0018909917132427486
#   ratio: 0.9995754281297708
#   speed_km_h: 0.8005720124966771
#   success_rate: 0.0
#   total_episodes: 10
#   total_loss: 1258.3743650583122
#   total_steps: 40000
#   total_time: 175.8625214099884
#   value_loss: 2516.752515411377
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter0.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#   1%|          | 80000/10000000 [04:01<8:14:27, 334.38it/s]
#  ===== ppo Training Iteration 1 =====:
#   adv_mean: -33.45475769042969
#   crash_sidewalk_rate: 0.047933333333333335
#   crash_vehicle_rate: 0.0
#   entropy: 2.820670573069499
#   episode_length: 3000.0
#   episode_reward: -3900.650516176224
#   frame_per_second: 274
#   grad_norm: 1354.8239765534033
#   idle_rate: 0.0
#   iteration: 1
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0005588143359487637
#   ratio: 0.9999832726823978
#   speed_km_h: 0.7777394130881866
#   success_rate: 0.0
#   total_episodes: 20
#   total_loss: 4017.745406713241
#   total_steps: 80000
#   total_time: 291.0761458873749
#   value_loss: 8035.491946958884
#   1%|          | 120000/10000000 [06:13<8:36:57, 318.53it/s]
#  ===== ppo Training Iteration 2 =====:
#   adv_mean: -11.418048858642578
#   crash_sidewalk_rate: 0.018033333333333332
#   crash_vehicle_rate: 0.0
#   entropy: 2.822150676525556
#   episode_length: 3000.0
#   episode_reward: -4002.393709874153
#   frame_per_second: 283
#   grad_norm: 646.8810340655156
#   idle_rate: 0.0
#   iteration: 2
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0011912728619511025
#   ratio: 1.0008458190239393
#   speed_km_h: 0.74449212324644
#   success_rate: 0.0
#   total_episodes: 40
#   total_loss: 2318.522113741361
#   total_steps: 120000
#   total_time: 423.73083662986755
#   value_loss: 4637.046619473971
#   2%|▏         | 160000/10000000 [08:07<8:15:35, 330.92it/s]
#  ===== ppo Training Iteration 3 =====:
#   adv_mean: -0.9781253933906555
#   crash_sidewalk_rate: 0.014833333333333334
#   crash_vehicle_rate: 0.0
#   entropy: 2.7776769259037115
#   episode_length: 3000.0
#   episode_reward: -3627.720588302612
#   frame_per_second: 297
#   grad_norm: 373.345100022585
#   idle_rate: 0.0
#   iteration: 3
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0006260385747270611
#   ratio: 0.9996659488250048
#   speed_km_h: 0.7103233189347664
#   success_rate: 0.0
#   total_episodes: 50
#   total_loss: 1036.4632962055696
#   total_steps: 160000
#   total_time: 537.4024488925934
#   value_loss: 2072.927842301589
#   2%|▏         | 200000/10000000 [09:51<7:48:07, 348.90it/s]
#  ===== ppo Training Iteration 4 =====:
#   adv_mean: 5.9205427169799805
#   crash_sidewalk_rate: 0.0054
#   crash_vehicle_rate: 0.0
#   entropy: 2.746745693989289
#   episode_length: 3000.0
#   episode_reward: -3110.7898534139
#   frame_per_second: 312
#   grad_norm: 197.22850254743528
#   idle_rate: 0.0
#   iteration: 4
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0008396309421349986
#   ratio: 0.999848527327562
#   speed_km_h: 0.6681253952987958
#   success_rate: 0.0
#   total_episodes: 60
#   total_loss: 338.92847261581664
#   total_steps: 200000
#   total_time: 640.9921541213989
#   value_loss: 677.8586232637748
#   2%|▏         | 240000/10000000 [11:26<7:20:06, 369.61it/s]
#  ===== ppo Training Iteration 5 =====:
#   adv_mean: 0.26105308532714844
#   crash_sidewalk_rate: 0.0131
#   crash_vehicle_rate: 0.0
#   entropy: 2.75597710670569
#   episode_length: 3000.0
#   episode_reward: -2643.3106922626494
#   frame_per_second: 325
#   grad_norm: 316.1372932042831
#   idle_rate: 0.0
#   iteration: 5
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0011757140424705516
#   ratio: 1.0004297866271092
#   speed_km_h: 0.6620203358976785
#   success_rate: 0.0
#   total_episodes: 80
#   total_loss: 827.2678637724656
#   total_steps: 240000
#   total_time: 736.6618959903717
#   value_loss: 1654.5380768604768
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter5.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#   3%|▎         | 280000/10000000 [13:13<7:15:50, 371.69it/s]
#  ===== ppo Training Iteration 6 =====:
#   adv_mean: -0.6696977019309998
#   crash_sidewalk_rate: 0.013166666666666667
#   crash_vehicle_rate: 0.0
#   entropy: 2.7364515310678725
#   episode_length: 3000.0
#   episode_reward: -2500.2264958911474
#   frame_per_second: 332
#   grad_norm: 283.04664372175165
#   idle_rate: 0.0
#   iteration: 6
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0006205406851875476
#   ratio: 1.0002706122704041
#   speed_km_h: 0.6484747924348098
#   success_rate: 0.0
#   total_episodes: 90
#   total_loss: 825.2864215606298
#   total_steps: 280000
#   total_time: 843.1218349933624
#   value_loss: 1650.574087025569
#   3%|▎         | 320000/10000000 [14:58<7:10:52, 374.43it/s]
#  ===== ppo Training Iteration 7 =====:
#   adv_mean: 4.82582950592041
#   crash_sidewalk_rate: 0.003833333333333333
#   crash_vehicle_rate: 0.0
#   entropy: 2.750126876739355
#   episode_length: 3000.0
#   episode_reward: -2311.9141278266907
#   frame_per_second: 337
#   grad_norm: 104.08408777285845
#   idle_rate: 0.0
#   iteration: 7
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.000471709045366599
#   ratio: 1.000510514432039
#   speed_km_h: 0.631688021876115
#   success_rate: 0.0
#   total_episodes: 100
#   total_loss: 185.44362607231506
#   total_steps: 320000
#   total_time: 948.2574963569641
#   value_loss: 370.8881947089464
#   4%|▎         | 360000/10000000 [16:55<7:21:45, 363.70it/s]
#  ===== ppo Training Iteration 8 =====:
#   adv_mean: -0.5435155034065247
#   crash_sidewalk_rate: 0.0028
#   crash_vehicle_rate: 0.0
#   entropy: 2.764031494122285
#   episode_length: 3000.0
#   episode_reward: -1769.872588701248
#   frame_per_second: 337
#   grad_norm: 236.89213367119814
#   idle_rate: 0.0
#   iteration: 8
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0006813005783045903
#   ratio: 0.9999804622087723
#   speed_km_h: 0.6334232352830143
#   success_rate: 0.0
#   total_episodes: 120
#   total_loss: 919.5539502755189
#   total_steps: 360000
#   total_time: 1065.1814765930176
#   value_loss: 1839.1092692644168
#   4%|▍         | 400000/10000000 [18:46<7:21:14, 362.61it/s]
#  ===== ppo Training Iteration 9 =====:
#   adv_mean: 3.238199234008789
#   crash_sidewalk_rate: 0.0055
#   crash_vehicle_rate: 0.0
#   entropy: 2.717484907309214
#   episode_length: 3000.0
#   episode_reward: -1297.7868864250183
#   frame_per_second: 340
#   grad_norm: 153.58834914427538
#   idle_rate: 0.0
#   iteration: 9
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.00016569435426320593
#   ratio: 0.9998095136040296
#   speed_km_h: 0.595366785610555
#   success_rate: 0.0
#   total_episodes: 130
#   total_loss: 288.85294064069404
#   total_steps: 400000
#   total_time: 1176.2339355945587
#   value_loss: 577.7062121232351
#   4%|▍         | 440000/10000000 [20:22<7:02:45, 376.89it/s]
#  ===== ppo Training Iteration 10 =====:
#   adv_mean: 5.818349838256836
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.690664219397765
#   episode_length: 3000.0
#   episode_reward: -1029.1231306362151
#   frame_per_second: 345
#   grad_norm: 24.011602218105242
#   idle_rate: 0.0
#   iteration: 10
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0003830121825628269
#   ratio: 0.9994579585698935
#   speed_km_h: 0.5789858899023648
#   success_rate: 0.0
#   total_episodes: 140
#   total_loss: 3.1965716600800174
#   total_steps: 440000
#   total_time: 1272.8008344173431
#   value_loss: 6.393909374108682
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter10.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#   5%|▍         | 480000/10000000 [21:59<6:49:27, 387.50it/s]
#  ===== ppo Training Iteration 11 =====:
#   adv_mean: 0.5956084728240967
#   crash_sidewalk_rate: 0.007033333333333333
#   crash_vehicle_rate: 0.0
#   entropy: 2.67175895464726
#   episode_length: 3000.0
#   episode_reward: -866.5023623371125
#   frame_per_second: 350
#   grad_norm: 209.4675886692145
#   idle_rate: 0.0
#   iteration: 11
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.00025332356647898754
#   ratio: 0.9999365254090382
#   speed_km_h: 0.6026346233214547
#   success_rate: 0.0
#   total_episodes: 160
#   total_loss: 384.83345988469245
#   total_steps: 480000
#   total_time: 1369.4607927799225
#   value_loss: 769.6674268037845
#   5%|▌         | 520000/10000000 [23:37<6:40:52, 394.13it/s]
#  ===== ppo Training Iteration 12 =====:
#   adv_mean: 3.8714022636413574
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.655274914931028
#   episode_length: 3000.0
#   episode_reward: -811.41018948555
#   frame_per_second: 354
#   grad_norm: 20.34956933764311
#   idle_rate: 0.0
#   iteration: 12
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0011880735254798753
#   ratio: 0.9997434431161636
#   speed_km_h: 0.594007710508329
#   success_rate: 0.0
#   total_episodes: 170
#   total_loss: 2.9319506528285832
#   total_steps: 520000
#   total_time: 1466.960956811905
#   value_loss: 5.866277455748656
#   6%|▌         | 560000/10000000 [25:10<6:29:46, 403.66it/s]
#  ===== ppo Training Iteration 13 =====:
#   adv_mean: 2.998955249786377
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.6516904797309486
#   episode_length: 3000.0
#   episode_reward: -615.5592494869232
#   frame_per_second: 358
#   grad_norm: 11.962656023716315
#   idle_rate: 0.0
#   iteration: 13
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0007313976416555353
#   ratio: 0.9994089598074938
#   speed_km_h: 0.6134640177621493
#   success_rate: 0.0
#   total_episodes: 180
#   total_loss: 1.579654491138764
#   total_steps: 560000
#   total_time: 1560.5039868354797
#   value_loss: 3.160771782772663
#   6%|▌         | 600000/10000000 [26:50<6:28:52, 402.88it/s]
#  ===== ppo Training Iteration 14 =====:
#   adv_mean: -5.400149822235107
#   crash_sidewalk_rate: 0.0108
#   crash_vehicle_rate: 0.0
#   entropy: 2.627784282121903
#   episode_length: 3000.0
#   episode_reward: -644.2028676605224
#   frame_per_second: 361
#   grad_norm: 370.01041302803236
#   idle_rate: 0.0
#   iteration: 14
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0002846862786473372
#   ratio: 1.000021129120619
#   speed_km_h: 0.6091916107199018
#   success_rate: 0.0
#   total_episodes: 200
#   total_loss: 873.5466315196111
#   total_steps: 600000
#   total_time: 1660.2567353248596
#   value_loss: 1747.0938346275916
#   6%|▋         | 640000/10000000 [28:34<6:33:14, 396.70it/s]
#  ===== ppo Training Iteration 15 =====:
#   adv_mean: -0.7078385949134827
#   crash_sidewalk_rate: 0.0067
#   crash_vehicle_rate: 0.0
#   entropy: 2.608684679483756
#   episode_length: 3000.0
#   episode_reward: -545.3435928440094
#   frame_per_second: 362
#   grad_norm: 255.55040739010542
#   idle_rate: 0.0
#   iteration: 15
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.00038046423160733705
#   ratio: 1.00022390744625
#   speed_km_h: 0.6057510840644723
#   success_rate: 0.0
#   total_episodes: 210
#   total_loss: 385.3469033326858
#   total_steps: 640000
#   total_time: 1764.6511204242706
#   value_loss: 770.6945671864045
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter15.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#   7%|▋         | 680000/10000000 [30:41<7:02:10, 367.94it/s]
#  ===== ppo Training Iteration 16 =====:
#   adv_mean: 1.7272226810455322
#   crash_sidewalk_rate: 0.0024666666666666665
#   crash_vehicle_rate: 0.0
#   entropy: 2.585196994818174
#   episode_length: 3000.0
#   episode_reward: -540.6982225894928
#   frame_per_second: 359
#   grad_norm: 154.1498011913055
#   idle_rate: 0.0
#   iteration: 16
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.000941879577928772
#   ratio: 0.9997960353126892
#   speed_km_h: 0.5970877411028019
#   success_rate: 0.0
#   total_episodes: 220
#   total_loss: 120.72787500711588
#   total_steps: 680000
#   total_time: 1891.6907703876495
#   value_loss: 241.45763346262467
#   7%|▋         | 720000/10000000 [32:24<6:52:55, 374.57it/s]
#  ===== ppo Training Iteration 17 =====:
#   adv_mean: 0.9248110055923462
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.605845042375418
#   episode_length: 3000.0
#   episode_reward: -506.677239151001
#   frame_per_second: 361
#   grad_norm: 184.08921932073739
#   idle_rate: 0.0
#   iteration: 17
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0002259709466344271
#   ratio: 0.9998266233083529
#   speed_km_h: 0.5742229209308065
#   success_rate: 0.0
#   total_episodes: 240
#   total_loss: 137.6229349637643
#   total_steps: 720000
#   total_time: 1994.024462223053
#   value_loss: 275.24632238057944
#   8%|▊         | 760000/10000000 [33:57<6:36:05, 388.80it/s]
#  ===== ppo Training Iteration 18 =====:
#   adv_mean: 1.0284109115600586
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.5996021127089475
#   episode_length: 3000.0
#   episode_reward: -506.8667192363739
#   frame_per_second: 364
#   grad_norm: 7.715752906524218
#   idle_rate: 0.0
#   iteration: 18
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0020226924001830273
#   ratio: 1.0000016526151927
#   speed_km_h: 0.5678441233418363
#   success_rate: 0.0
#   total_episodes: 250
#   total_loss: 0.7381601091951896
#   total_steps: 760000
#   total_time: 2087.8032174110413
#   value_loss: 1.48036560337895
#   8%|▊         | 800000/10000000 [35:31<6:24:00, 399.30it/s]
#  ===== ppo Training Iteration 19 =====:
#   adv_mean: 1.012955665588379
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.5703699273940845
#   episode_length: 3000.0
#   episode_reward: -401.5650563621521
#   frame_per_second: 366
#   grad_norm: 5.185944173274896
#   idle_rate: 0.0
#   iteration: 19
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0009662035760881665
#   ratio: 1.0000416913475745
#   speed_km_h: 0.5800734093209504
#   success_rate: 0.0
#   total_episodes: 260
#   total_loss: 0.48505374445365024
#   total_steps: 800000
#   total_time: 2181.667031288147
#   value_loss: 0.9720398951608401
#   8%|▊         | 840000/10000000 [37:08<6:18:26, 403.42it/s]
#  ===== ppo Training Iteration 20 =====:
#   adv_mean: 1.4043687582015991
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.554160333596743
#   episode_length: 3000.0
#   episode_reward: -401.92596382141113
#   frame_per_second: 368
#   grad_norm: 8.055449615571744
#   idle_rate: 0.0
#   iteration: 20
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.00017021031309969915
#   ratio: 1.0001135640801528
#   speed_km_h: 0.573060866079475
#   success_rate: 0.0
#   total_episodes: 280
#   total_loss: 0.7491661394301515
#   total_steps: 840000
#   total_time: 2278.3686254024506
#   value_loss: 1.4986726988489047
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter20.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#   9%|▉         | 880000/10000000 [38:38<6:06:38, 414.57it/s]
#  ===== ppo Training Iteration 21 =====:
#   adv_mean: 0.5140870809555054
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.57332818874946
#   episode_length: 3000.0
#   episode_reward: -335.21196301460265
#   frame_per_second: 371
#   grad_norm: 2.172928837247384
#   idle_rate: 0.0
#   iteration: 21
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0011403201287463068
#   ratio: 0.999961101091825
#   speed_km_h: 0.5761157306232473
#   success_rate: 0.0
#   total_episodes: 290
#   total_loss: 0.13395746431017938
#   total_steps: 880000
#   total_time: 2368.7064304351807
#   value_loss: 0.27019557078870443
#   9%|▉         | 920000/10000000 [40:10<5:59:13, 421.27it/s]
#  ===== ppo Training Iteration 22 =====:
#   adv_mean: 0.5513573288917542
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.5343817959993316
#   episode_length: 3000.0
#   episode_reward: -173.55305802345276
#   frame_per_second: 373
#   grad_norm: 1.9449945125824366
#   idle_rate: 0.0
#   iteration: 22
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0008048877521501615
#   ratio: 1.0001977026080473
#   speed_km_h: 0.5848626299408848
#   success_rate: 0.0
#   total_episodes: 300
#   total_loss: 0.08830860644229688
#   total_steps: 920000
#   total_time: 2460.078712940216
#   value_loss: 0.17822698751368965
#  10%|▉         | 960000/10000000 [41:45<5:57:33, 421.38it/s]
#  ===== ppo Training Iteration 23 =====:
#   adv_mean: 0.7204428315162659
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.512160214094015
#   episode_length: 3000.0
#   episode_reward: -36.164106149673465
#   frame_per_second: 375
#   grad_norm: 2.002444745103518
#   idle_rate: 0.0
#   iteration: 23
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0011008113176406672
#   ratio: 0.9999993608930172
#   speed_km_h: 0.594860632262182
#   success_rate: 0.0
#   total_episodes: 320
#   total_loss: 0.10817364925811163
#   total_steps: 960000
#   total_time: 2554.9424211978912
#   value_loss: 0.21854892153149613
#  10%|█         | 1000000/10000000 [43:30<6:07:30, 408.15it/s]
#  ===== ppo Training Iteration 24 =====:
#   adv_mean: 0.4593532681465149
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.5209643244743347
#   episode_length: 3000.0
#   episode_reward: 12.910435228347778
#   frame_per_second: 375
#   grad_norm: 1.6226673715962814
#   idle_rate: 0.0
#   iteration: 24
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0019796587134269664
#   ratio: 0.999954142440588
#   speed_km_h: 0.6440913218968263
#   success_rate: 0.0
#   total_episodes: 330
#   total_loss: 0.05619900084223049
#   total_steps: 1000000
#   total_time: 2660.1183822155
#   value_loss: 0.11635731950115699
#  10%|█         | 1040000/10000000 [45:03<6:00:28, 414.27it/s]
#  ===== ppo Training Iteration 25 =====:
#   adv_mean: 0.5620045065879822
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.489710378188353
#   episode_length: 3000.0
#   episode_reward: 13.841758432388305
#   frame_per_second: 377
#   grad_norm: 1.5524693554983688
#   idle_rate: 0.0
#   iteration: 25
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0028096791623960227
#   ratio: 1.0004106529248067
#   speed_km_h: 0.6437023448302198
#   success_rate: 0.0
#   total_episodes: 340
#   total_loss: 0.04194779044855983
#   total_steps: 1040000
#   total_time: 2753.228217124939
#   value_loss: 0.08951493842969052
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter25.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#  11%|█         | 1080000/10000000 [46:44<6:04:05, 408.33it/s]
#  ===== ppo Training Iteration 26 =====:
#   adv_mean: 0.734523355960846
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.423895426438405
#   episode_length: 3000.0
#   episode_reward: 17.169948511123657
#   frame_per_second: 378
#   grad_norm: 1.7857967164845039
#   idle_rate: 0.0
#   iteration: 26
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0037930776572559412
#   ratio: 1.0000519423530652
#   speed_km_h: 0.7398330718831233
#   success_rate: 0.0
#   total_episodes: 360
#   total_loss: 0.06432907370751939
#   total_steps: 1080000
#   total_time: 2854.532506465912
#   value_loss: 0.13624430179524308
#  11%|█         | 1120000/10000000 [48:18<5:57:51, 413.58it/s]
#  ===== ppo Training Iteration 27 =====:
#   adv_mean: 0.6101490259170532
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.4105387065655144
#   episode_length: 3000.0
#   episode_reward: 20.28538453102112
#   frame_per_second: 379
#   grad_norm: 1.584600183673394
#   idle_rate: 0.0
#   iteration: 27
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.009529721059758836
#   ratio: 1.0005701729502434
#   speed_km_h: 0.8600052528763329
#   success_rate: 0.0
#   total_episodes: 370
#   total_loss: 0.022275487031546595
#   total_steps: 1120000
#   total_time: 2948.360565662384
#   value_loss: 0.06361041730030989
#  12%|█▏        | 1160000/10000000 [49:50<5:51:32, 419.11it/s]
#  ===== ppo Training Iteration 28 =====:
#   adv_mean: 0.7556924223899841
#   crash_sidewalk_rate: 0.0
#   crash_vehicle_rate: 0.0
#   entropy: 2.261527949113112
#   episode_length: 3000.0
#   episode_reward: 25.772677850723266
#   frame_per_second: 381
#   grad_norm: 1.756282995049006
#   idle_rate: 0.0
#   iteration: 28
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.01869607814035426
#   ratio: 1.000209229802474
#   speed_km_h: 1.164117123854406
#   success_rate: 0.0
#   total_episodes: 380
#   total_loss: 0.02104999712647464
#   total_steps: 1160000
#   total_time: 3040.8213152885437
#   value_loss: 0.07949215023038098
#  12%|█▏        | 1200000/10000000 [51:35<6:00:01, 407.37it/s]
#  ===== ppo Training Iteration 29 =====:
#   adv_mean: 0.8476511836051941
#   crash_sidewalk_rate: 0.0001
#   crash_vehicle_rate: 0.0
#   entropy: 2.192125911131883
#   episode_length: 3000.0
#   episode_reward: 43.48908485056525
#   frame_per_second: 381
#   grad_norm: 4.461446065981036
#   idle_rate: 0.0
#   iteration: 29
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.004579622041992246
#   ratio: 0.9990183517336846
#   speed_km_h: 1.7020768978322234
#   success_rate: 0.0
#   total_episodes: 400
#   total_loss: 2.3057326682786554
#   total_steps: 1200000
#   total_time: 3145.421183824539
#   value_loss: 4.620624548578873
#  12%|█▏        | 1240000/10000000 [53:12<5:56:46, 409.22it/s]
#  ===== ppo Training Iteration 30 =====:
#   adv_mean: 0.39935073256492615
#   crash_sidewalk_rate: 0.0013333333333333333
#   crash_vehicle_rate: 0.0
#   entropy: 2.301066937507727
#   episode_length: 3000.0
#   episode_reward: 46.39173863959842
#   frame_per_second: 382
#   grad_norm: 20.633873227620736
#   idle_rate: 0.0
#   iteration: 30
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.000729257235966193
#   ratio: 1.0001477158222443
#   speed_km_h: 2.919635634258682
#   success_rate: 0.0
#   total_episodes: 410
#   total_loss: 51.30347076925712
#   total_steps: 1240000
#   total_time: 3242.1098725795746
#   value_loss: 102.60840011391885
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter30.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#  13%|█▎        | 1280000/10000000 [54:47<5:52:03, 412.81it/s]
#  ===== ppo Training Iteration 31 =====:
#   adv_mean: -1.750600814819336
#   crash_sidewalk_rate: 0.004966666666666667
#   crash_vehicle_rate: 0.0
#   entropy: 2.237806484943781
#   episode_length: 3000.0
#   episode_reward: 41.92377039100215
#   frame_per_second: 383
#   grad_norm: 169.78830885948278
#   idle_rate: 0.0
#   iteration: 31
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0012367626756596833
#   ratio: 0.9999675877965414
#   speed_km_h: 3.6210607789280793
#   success_rate: 0.0
#   total_episodes: 420
#   total_loss: 451.2781602541606
#   total_steps: 1280000
#   total_time: 3337.0412838459015
#   value_loss: 902.558795984586
#  13%|█▎        | 1320000/10000000 [57:00<6:30:05, 370.85it/s]
#  ===== ppo Training Iteration 32 =====:
#   adv_mean: -2.873927593231201
#   crash_sidewalk_rate: 0.005633333333333333
#   crash_vehicle_rate: 0.0
#   entropy: 2.134555042707003
#   episode_length: 3000.0
#   episode_reward: -81.03258908731553
#   frame_per_second: 380
#   grad_norm: 204.41657313444676
#   idle_rate: 0.0
#   iteration: 32
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0054151521691192805
#   ratio: 0.9992342420113393
#   speed_km_h: 3.2538871160959526
#   success_rate: 0.0
#   total_episodes: 440
#   total_loss: 316.1444233894348
#   total_steps: 1320000
#   total_time: 3470.4829909801483
#   value_loss: 632.299680802761
#  14%|█▎        | 1360000/10000000 [58:38<6:17:57, 380.99it/s]
#  ===== ppo Training Iteration 33 =====:
#   adv_mean: -5.224826812744141
#   crash_sidewalk_rate: 0.009933333333333334
#   crash_vehicle_rate: 0.0
#   entropy: 2.199827691836235
#   episode_length: 3000.0
#   episode_reward: -98.88995026263332
#   frame_per_second: 381
#   grad_norm: 541.9432787711804
#   idle_rate: 0.0
#   iteration: 33
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0009861779670851925
#   ratio: 1.0000801304211984
#   speed_km_h: 4.380450962440841
#   success_rate: 0.0
#   total_episodes: 450
#   total_loss: 1257.8352613430757
#   total_steps: 1360000
#   total_time: 3568.770842552185
#   value_loss: 2515.6724923427287
#  14%|█▍        | 1400000/10000000 [1:00:16<6:08:35, 388.86it/s]
#  ===== ppo Training Iteration 34 =====:
#   adv_mean: -3.3724703788757324
#   crash_sidewalk_rate: 0.0024
#   crash_vehicle_rate: 0.0
#   entropy: 2.1468276910292796
#   episode_length: 3000.0
#   episode_reward: -311.1884204095837
#   frame_per_second: 381
#   grad_norm: 743.7513678037203
#   idle_rate: 0.0
#   iteration: 34
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.0007162302326506529
#   ratio: 0.9997491167523922
#   speed_km_h: 4.2356013151047796
#   success_rate: 0.0
#   total_episodes: 460
#   total_loss: 1380.8350187277183
#   total_steps: 1400000
#   total_time: 3666.696287870407
#   value_loss: 2761.6714688374445
#  14%|█▍        | 1440000/10000000 [1:02:03<6:11:04, 384.46it/s]
#  ===== ppo Training Iteration 35 =====:
#   adv_mean: 1.1397074460983276
#   crash_sidewalk_rate: 0.0017333333333333333
#   crash_vehicle_rate: 0.0
#   entropy: 2.0805289731575893
#   episode_length: 3000.0
#   episode_reward: -360.7903544723629
#   frame_per_second: 381
#   grad_norm: 291.90708864040863
#   idle_rate: 0.0
#   iteration: 35
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.004622218418173874
#   ratio: 0.9995235232206491
#   speed_km_h: 3.5516741839470605
#   success_rate: 0.0
#   total_episodes: 480
#   total_loss: 263.3463754812876
#   total_steps: 1440000
#   total_time: 3773.40381193161
#   value_loss: 526.7019944337699
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter35.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#  15%|█▍        | 1480000/10000000 [1:03:44<6:06:33, 387.39it/s]
#  ===== ppo Training Iteration 36 =====:
#   adv_mean: 2.1184754371643066
#   crash_sidewalk_rate: 6.666666666666667e-05
#   crash_vehicle_rate: 0.0
#   entropy: 2.056940010877756
#   episode_length: 3000.0
#   episode_reward: -335.2069503466906
#   frame_per_second: 381
#   grad_norm: 22.05048542022705
#   idle_rate: 0.0
#   iteration: 36
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.007109719348731092
#   ratio: 1.000450239273218
#   speed_km_h: 4.471953768616822
#   success_rate: 0.0
#   total_episodes: 490
#   total_loss: 4.3438261942221565
#   total_steps: 1480000
#   total_time: 3874.89609003067
#   value_loss: 8.701871788807404
#  15%|█▌        | 1520000/10000000 [1:05:26<6:02:51, 389.49it/s]
#  ===== ppo Training Iteration 37 =====:
#   adv_mean: 2.003269910812378
#   crash_sidewalk_rate: 6.666666666666667e-05
#   crash_vehicle_rate: 0.0
#   entropy: 2.065581342501518
#   episode_length: 3000.0
#   episode_reward: -302.85913989999466
#   frame_per_second: 382
#   grad_norm: 9.665486269195874
#   idle_rate: 0.0
#   iteration: 37
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.01314533009665469
#   ratio: 1.0015245139216766
#   speed_km_h: 5.582270222882565
#   success_rate: 0.0
#   total_episodes: 500
#   total_loss: 2.2199782230533085
#   total_steps: 1520000
#   total_time: 3976.285977602005
#   value_loss: 4.466247109801341
#  16%|█▌        | 1560000/10000000 [1:07:11<6:03:40, 386.80it/s]
#  ===== ppo Training Iteration 38 =====:
#   adv_mean: 1.8824222087860107
#   crash_sidewalk_rate: 0.0011333333333333334
#   crash_vehicle_rate: 0.0
#   entropy: 1.9814612325185383
#   episode_length: 3000.0
#   episode_reward: -202.34584875931944
#   frame_per_second: 382
#   grad_norm: 29.545823370951872
#   idle_rate: 0.0
#   iteration: 38
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.003191486678313082
#   ratio: 0.9998778963318238
#   speed_km_h: 8.271555205853527
#   success_rate: 0.0
#   total_episodes: 520
#   total_loss: 61.60780045390129
#   total_steps: 1560000
#   total_time: 4081.3652682304382
#   value_loss: 123.221984150318
#  16%|█▌        | 1600000/10000000 [1:08:48<5:54:57, 394.42it/s]
#  ===== ppo Training Iteration 39 =====:
#   adv_mean: 4.182741165161133
#   crash_sidewalk_rate: 0.00046666666666666666
#   crash_vehicle_rate: 0.0
#   entropy: 1.864354886764135
#   episode_length: 3000.0
#   episode_reward: -41.13000625121097
#   frame_per_second: 382
#   grad_norm: 21.03447673511811
#   idle_rate: 0.0
#   iteration: 39
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.006280710964720362
#   ratio: 1.000605318790827
#   speed_km_h: 13.2297712483118
#   success_rate: 0.0
#   total_episodes: 530
#   total_loss: 16.493523194698188
#   total_steps: 1600000
#   total_time: 4178.125594615936
#   value_loss: 32.999607587471985
#  16%|█▋        | 1640000/10000000 [1:10:28<5:51:45, 396.10it/s]
#  ===== ppo Training Iteration 40 =====:
#   adv_mean: 5.897797107696533
#   crash_sidewalk_rate: 0.0011333333333333334
#   crash_vehicle_rate: 0.0
#   entropy: 1.7350577958119222
#   episode_length: 3000.0
#   episode_reward: 149.7843848061881
#   frame_per_second: 383
#   grad_norm: 34.75798287834876
#   idle_rate: 0.0
#   iteration: 40
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 1.0
#   policy_loss: -0.006022815611392546
#   ratio: 1.0003788645450886
#   speed_km_h: 19.637047908139113
#   success_rate: 0.0
#   total_episodes: 540
#   total_loss: 28.451832754489704
#   total_steps: 1640000
#   total_time: 4278.0871551036835
#   value_loss: 56.91571090251971
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter40.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#  17%|█▋        | 1680000/10000000 [1:12:26<6:07:40, 377.14it/s]
#  ===== ppo Training Iteration 41 =====:
#   adv_mean: 3.1118457317352295
#   crash_sidewalk_rate: 0.0062
#   crash_vehicle_rate: 0.0
#   entropy: 1.7144587099552155
#   episode_length: 2991.41
#   episode_reward: 616.0212286130444
#   frame_per_second: 382
#   grad_norm: 192.08788227668174
#   idle_rate: 0.0
#   iteration: 41
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.95
#   policy_loss: -0.00611322329690059
#   ratio: 0.9996988751567327
#   speed_km_h: 26.099968071245673
#   success_rate: 0.05
#   total_episodes: 560
#   total_loss: 306.2738305238577
#   total_steps: 1680000
#   total_time: 4396.020091533661
#   value_loss: 612.5598881305792
#  17%|█▋        | 1720000/10000000 [1:14:19<6:13:26, 369.54it/s]
#  ===== ppo Training Iteration 42 =====:
#   adv_mean: 6.978631973266602
#   crash_sidewalk_rate: 0.0031333333333333335
#   crash_vehicle_rate: 0.0
#   entropy: 1.5856446211154644
#   episode_length: 2977.44
#   episode_reward: 829.9431833301591
#   frame_per_second: 381
#   grad_norm: 139.87174684817975
#   idle_rate: 0.0
#   iteration: 42
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.87
#   policy_loss: -0.0046107450204987965
#   ratio: 0.999512344560562
#   speed_km_h: 26.627007452126676
#   success_rate: 0.13
#   total_episodes: 570
#   total_loss: 100.0933888215285
#   total_steps: 1720000
#   total_time: 4509.339593172073
#   value_loss: 200.1959987273583
#  18%|█▊        | 1760000/10000000 [1:16:32<6:37:30, 345.49it/s]
#  ===== ppo Training Iteration 43 =====:
#   adv_mean: 7.687743186950684
#   crash_sidewalk_rate: 0.0018
#   crash_vehicle_rate: 0.0
#   entropy: 1.5058314889669417
#   episode_length: 2919.8
#   episode_reward: 1111.010905833455
#   frame_per_second: 379
#   grad_norm: 121.80326648981143
#   idle_rate: 0.0
#   iteration: 43
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.72
#   policy_loss: -0.0042909038665805916
#   ratio: 0.9997386052822456
#   speed_km_h: 29.86008469915207
#   success_rate: 0.28
#   total_episodes: 585
#   total_loss: 82.84600947575692
#   total_steps: 1760000
#   total_time: 4642.703220367432
#   value_loss: 165.70060023283347
#  18%|█▊        | 1800000/10000000 [1:18:30<6:37:04, 344.19it/s]
#  ===== ppo Training Iteration 44 =====:
#   adv_mean: 9.83171558380127
#   crash_sidewalk_rate: 0.0012333333333333332
#   crash_vehicle_rate: 0.0
#   entropy: 1.3797722162344517
#   episode_length: 2786.07
#   episode_reward: 1408.1439652582953
#   frame_per_second: 378
#   grad_norm: 99.90781915187836
#   idle_rate: 0.0
#   iteration: 44
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.54
#   policy_loss: -0.003814566971358055
#   ratio: 1.0005204282127893
#   speed_km_h: 36.2116342990597
#   success_rate: 0.46
#   total_episodes: 603
#   total_loss: 38.183822754101875
#   total_steps: 1800000
#   total_time: 4759.93785905838
#   value_loss: 76.37527463619526
#  18%|█▊        | 1840000/10000000 [1:20:31<6:40:44, 339.37it/s]
#  ===== ppo Training Iteration 45 =====:
#   adv_mean: 8.927010536193848
#   crash_sidewalk_rate: 0.0018
#   crash_vehicle_rate: 0.0
#   entropy: 1.3284859742109592
#   episode_length: 2578.53
#   episode_reward: 1716.099396127159
#   frame_per_second: 376
#   grad_norm: 135.07645515539707
#   idle_rate: 0.0
#   iteration: 45
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.33
#   policy_loss: -0.0026496376795992734
#   ratio: 1.000154631680403
#   speed_km_h: 40.06076669765018
#   success_rate: 0.67
#   total_episodes: 624
#   total_loss: 70.66294604814969
#   total_steps: 1840000
#   total_time: 4881.579626321793
#   value_loss: 141.33119145417825
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter45.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#  19%|█▉        | 1880000/10000000 [1:22:35<6:45:02, 334.12it/s]
#  ===== ppo Training Iteration 46 =====:
#   adv_mean: -3.8363733291625977
#   crash_sidewalk_rate: 0.021766666666666667
#   crash_vehicle_rate: 0.0
#   entropy: 1.3125046476339683
#   episode_length: 2313.53
#   episode_reward: 1604.120466430445
#   frame_per_second: 375
#   grad_norm: 1898.3674780038687
#   idle_rate: 3.3333333333333335e-05
#   iteration: 46
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.1
#   policy_loss: -3.1922834638792735e-05
#   ratio: 1.0000974396864573
#   speed_km_h: 41.105643117495404
#   success_rate: 0.88
#   total_episodes: 647
#   total_loss: 3647.4729635727713
#   total_steps: 1880000
#   total_time: 5005.693961143494
#   value_loss: 7294.945974555382
#  19%|█▉        | 1920000/10000000 [1:24:37<6:45:19, 332.24it/s]
#  ===== ppo Training Iteration 47 =====:
#   adv_mean: 9.372822761535645
#   crash_sidewalk_rate: 0.0020666666666666667
#   crash_vehicle_rate: 0.0
#   entropy: 1.2302209723454256
#   episode_length: 2050.75
#   episode_reward: 1753.526007018103
#   frame_per_second: 374
#   grad_norm: 266.01979512923805
#   idle_rate: 0.0
#   iteration: 47
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.002741652227884445
#   ratio: 1.000232526125052
#   speed_km_h: 43.88592915813965
#   success_rate: 0.98
#   total_episodes: 670
#   total_loss: 120.71250978127505
#   total_steps: 1920000
#   total_time: 5127.673795223236
#   value_loss: 241.43050306760347
#  20%|█▉        | 1960000/10000000 [1:26:46<6:51:37, 325.54it/s]
#  ===== ppo Training Iteration 48 =====:
#   adv_mean: 8.540942192077637
#   crash_sidewalk_rate: 0.0018666666666666666
#   crash_vehicle_rate: 0.0
#   entropy: 1.1995154133973978
#   episode_length: 1855.52
#   episode_reward: 1764.3680837474378
#   frame_per_second: 372
#   grad_norm: 190.27760114180737
#   idle_rate: 0.0
#   iteration: 48
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0016579200283815272
#   ratio: 0.9998861248294513
#   speed_km_h: 47.37636097801451
#   success_rate: 0.98
#   total_episodes: 691
#   total_loss: 82.58388442259569
#   total_steps: 1960000
#   total_time: 5256.333609819412
#   value_loss: 165.1710848343678
#  20%|██        | 2000000/10000000 [1:29:21<7:22:00, 301.65it/s]
#  ===== ppo Training Iteration 49 =====:
#   adv_mean: -0.8547444343566895
#   crash_sidewalk_rate: 0.014866666666666667
#   crash_vehicle_rate: 0.0
#   entropy: 1.150370611365025
#   episode_length: 1720.44
#   episode_reward: 1554.2147032362677
#   frame_per_second: 369
#   grad_norm: 1686.9902920062725
#   idle_rate: 3.3333333333333335e-05
#   iteration: 49
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0009430734049648237
#   ratio: 0.9999515055463865
#   speed_km_h: 48.09917606509437
#   success_rate: 0.96
#   total_episodes: 720
#   total_loss: 2454.9425238682675
#   total_steps: 2000000
#   total_time: 5411.6242389678955
#   value_loss: 4909.886958665114
#  20%|██        | 2040000/10000000 [1:31:33<7:18:35, 302.48it/s]
#  ===== ppo Training Iteration 50 =====:
#   adv_mean: 6.919715404510498
#   crash_sidewalk_rate: 0.003266666666666667
#   crash_vehicle_rate: 0.0
#   entropy: 1.0676367809375127
#   episode_length: 1641.52
#   episode_reward: 1833.9774221865102
#   frame_per_second: 368
#   grad_norm: 344.7824145634969
#   idle_rate: 0.0
#   iteration: 50
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0012822678321614289
#   ratio: 1.0001583568942853
#   speed_km_h: 49.83303109814458
#   success_rate: 0.97
#   total_episodes: 745
#   total_loss: 177.45129227026914
#   total_steps: 2040000
#   total_time: 5542.93300652504
#   value_loss: 354.90514888763425
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter50.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#  21%|██        | 2080000/10000000 [1:33:36<7:07:34, 308.72it/s]
#  ===== ppo Training Iteration 51 =====:
#   adv_mean: 6.201610565185547
#   crash_sidewalk_rate: 0.0034666666666666665
#   crash_vehicle_rate: 0.0
#   entropy: 1.049000744215953
#   episode_length: 1582.51
#   episode_reward: 1815.7054831796058
#   frame_per_second: 367
#   grad_norm: 291.1414753913879
#   idle_rate: 0.0
#   iteration: 51
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0009851782827470928
#   ratio: 1.0002908707429201
#   speed_km_h: 50.87005238619835
#   success_rate: 0.97
#   total_episodes: 770
#   total_loss: 156.8062534014384
#   total_steps: 2080000
#   total_time: 5666.348487138748
#   value_loss: 313.61447711357704
#  21%|██        | 2120000/10000000 [1:35:47<7:06:45, 307.75it/s]
#  ===== ppo Training Iteration 52 =====:
#   adv_mean: 5.8360276222229
#   crash_sidewalk_rate: 0.0029
#   crash_vehicle_rate: 0.0
#   entropy: 1.029135486445366
#   episode_length: 1531.49
#   episode_reward: 1801.6306128914541
#   frame_per_second: 365
#   grad_norm: 238.30840716484266
#   idle_rate: 0.0
#   iteration: 52
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0020556084011705256
#   ratio: 0.9998500226399838
#   speed_km_h: 52.562524108547905
#   success_rate: 0.97
#   total_episodes: 798
#   total_loss: 105.53220377701979
#   total_steps: 2120000
#   total_time: 5797.2731738090515
#   value_loss: 211.06851909344013
#  22%|██▏       | 2160000/10000000 [1:37:59<7:06:50, 306.13it/s]
#  ===== ppo Training Iteration 53 =====:
#   adv_mean: 4.077315330505371
#   crash_sidewalk_rate: 0.0035
#   crash_vehicle_rate: 0.0
#   entropy: 0.9702354031495559
#   episode_length: 1468.28
#   episode_reward: 1944.5664595992507
#   frame_per_second: 364
#   grad_norm: 282.32280477866146
#   idle_rate: 0.0
#   iteration: 53
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0009206712666081073
#   ratio: 1.0002871591311235
#   speed_km_h: 54.04384681718332
#   success_rate: 0.97
#   total_episodes: 829
#   total_loss: 178.66226763847547
#   total_steps: 2160000
#   total_time: 5929.562437295914
#   value_loss: 357.32637629386704
#  22%|██▏       | 2200000/10000000 [1:40:09<7:03:22, 307.06it/s]
#  ===== ppo Training Iteration 54 =====:
#   adv_mean: 4.571727275848389
#   crash_sidewalk_rate: 0.0036333333333333335
#   crash_vehicle_rate: 0.0
#   entropy: 0.9369861800319109
#   episode_length: 1426.68
#   episode_reward: 1941.5168157422686
#   frame_per_second: 363
#   grad_norm: 243.55797417469515
#   idle_rate: 0.0
#   iteration: 54
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.000740702336994358
#   ratio: 0.999596155453951
#   speed_km_h: 55.83527998402648
#   success_rate: 0.97
#   total_episodes: 858
#   total_loss: 116.52147363516
#   total_steps: 2200000
#   total_time: 6058.892865419388
#   value_loss: 233.04442895742562
#  22%|██▏       | 2240000/10000000 [1:42:47<7:28:53, 288.12it/s]
#  ===== ppo Training Iteration 55 =====:
#   adv_mean: -5.04928731918335
#   crash_sidewalk_rate: 0.007866666666666666
#   crash_vehicle_rate: 0.0
#   entropy: 0.9113438499279511
#   episode_length: 1379.41
#   episode_reward: 1697.9465193962628
#   frame_per_second: 360
#   grad_norm: 1891.5493252876477
#   idle_rate: 3.3333333333333335e-05
#   iteration: 55
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -2.9928290631431036e-05
#   ratio: 1.0000668046948238
#   speed_km_h: 56.365726715340514
#   success_rate: 0.94
#   total_episodes: 887
#   total_loss: 2353.556287335127
#   total_steps: 2240000
#   total_time: 6217.611770868301
#   value_loss: 4707.112633240528
#
# Trainer is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\checkpoint-iter55.pkl>. Progress is saved at <C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo\progress.csv>.
#  23%|██▎       | 2280000/10000000 [1:45:01<7:21:39, 291.33it/s]
#  ===== ppo Training Iteration 56 =====:
#   adv_mean: -4.007869243621826
#   crash_sidewalk_rate: 0.0181
#   crash_vehicle_rate: 0.0
#   entropy: 0.8948790045120777
#   episode_length: 1349.89
#   episode_reward: 1476.8755785214523
#   frame_per_second: 358
#   grad_norm: 2300.173952738444
#   idle_rate: 6.666666666666667e-05
#   iteration: 56
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0012092693413321214
#   ratio: 0.9996955795547902
#   speed_km_h: 56.74180568145074
#   success_rate: 0.92
#   total_episodes: 917
#   total_loss: 2503.5642704596885
#   total_steps: 2280000
#   total_time: 6351.4413866996765
#   value_loss: 5007.130947895539
#  23%|██▎       | 2320000/10000000 [1:47:12<7:12:50, 295.72it/s]
#  ===== ppo Training Iteration 57 =====:
#   adv_mean: 3.7698848247528076
#   crash_sidewalk_rate: 0.0046
#   crash_vehicle_rate: 0.0
#   entropy: 0.8551113566909081
#   episode_length: 1350.17
#   episode_reward: 1483.7308872729866
#   frame_per_second: 357
#   grad_norm: 643.7798517471705
#   idle_rate: 0.0
#   iteration: 57
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0014863831446303103
#   ratio: 1.0009017752149165
#   speed_km_h: 56.43156065031856
#   success_rate: 0.93
#   total_episodes: 946
#   total_loss: 352.4413730132274
#   total_steps: 2320000
#   total_time: 6481.950868844986
#   value_loss: 704.8857177147498
#  24%|██▎       | 2360000/10000000 [1:49:20<7:04:07, 300.23it/s]
#  ===== ppo Training Iteration 58 =====:
#   adv_mean: 2.3355627059936523
#   crash_sidewalk_rate: 0.0067666666666666665
#   crash_vehicle_rate: 0.0
#   entropy: 0.8428717797383284
#   episode_length: 1343.59
#   episode_reward: 1640.5513492666266
#   frame_per_second: 357
#   grad_norm: 964.3747257281573
#   idle_rate: 0.0
#   iteration: 58
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.0006541373879045773
#   ratio: 0.9994822976298822
#   speed_km_h: 57.06666766787935
#   success_rate: 0.95
#   total_episodes: 976
#   total_loss: 628.1682906175271
#   total_steps: 2360000
#   total_time: 6610.438995838165
#   value_loss: 1256.3378870352722
#  24%|██▍       | 2400000/10000000 [1:51:32<7:00:38, 301.13it/s]
#  ===== ppo Training Iteration 59 =====:
#   adv_mean: -1.7220488786697388
#   crash_sidewalk_rate: 0.012133333333333333
#   crash_vehicle_rate: 0.0
#   entropy: 0.816374663129831
#   episode_length: 1339.61
#   episode_reward: 1537.5857239517477
#   frame_per_second: 355
#   grad_norm: 1806.0892392867652
#   idle_rate: 3.3333333333333335e-05
#   iteration: 59
#   log_dir: C:\Users\blerd\Desktop\assignment4\train_ppo_in_single_agent_env\ppo
#   max_step_rate: 0.0
#   policy_loss: -0.00027032538200728596
#   ratio: 1.0001264721537249
#   speed_km_h: 57.3685851503173
#   success_rate: 0.92
#   total_episodes: 1005
#   total_loss: 1509.9581103887313
#   total_steps: 2400000
#   total_time: 6742.340738773346
#   value_loss: 3019.9167708763707
#  24%|██▍       | 2400000/10000000 [1:52:08<5:55:05, 356.72it/s]
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File c:\Users\blerd\anaconda3\envs\cs260r\Lib\multiprocessing\connection.py:311, in PipeConnection._recv_bytes(self, maxsize)
#     310 finally:
# --> 311     nread, err = ov.GetOverlappedResult(True)
#     312     if err == 0:
#
# BrokenPipeError: [WinError 109] The pipe has been ended
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# File ~\Desktop\assignment4\train_ppo_in_singleagent_env.py:284
#     280 cpu_actions = actions.cpu().numpy()
#     282 # Step the environment
#     283 obs, reward, done, info, masks, total_episodes, \
# --> 284 total_steps, episode_rewards = step_envs(
#     285     cpu_actions=cpu_actions,
#     286     envs=envs,
#     287     episode_rewards=episode_rewards,
#     288     result_recorder=result_recorder,
#     289     total_steps=total_steps,
#     290     total_episodes=total_episodes,
#     291     device=config.device
#     292 )
#     294 rewards = torch.from_numpy(
#     295     reward.astype(np.float32)).view(-1, 1).to(config.device)
#     297 # Store samples
#
# File ~\Desktop\assignment4\core\utils.py:40, in step_envs(cpu_actions, envs, episode_rewards, result_recorder, total_steps, total_episodes, device)
#      36 def step_envs(*, cpu_actions, envs, episode_rewards, result_recorder, total_steps, total_episodes,
#      37               device):
#      38     """Step the vectorized environments for one step. Process the reward
#      39     recording and terminal states."""
# ---> 40     obs, reward, done, info = envs.step(cpu_actions)
#      41     episode_rewards += reward.reshape(episode_rewards.shape)
#      42     episode_rewards_old_shape = episode_rewards.shape
#
# File ~\Desktop\assignment4\core\envs.py:297, in VecEnv.step(self, actions)
#     289 """
#     290 Step the environments with the given action
#     291
#    (...)
#     294 reward, done, information
#     295 """
#     296 self.step_async(actions)
# --> 297 return self.step_wait()
#
# File ~\Desktop\assignment4\core\envs.py:616, in SubprocVecEnv.step_wait(self)
#     615 def step_wait(self):
# --> 616     results = [remote.recv() for remote in self.remotes]
#     617     self.waiting = False
#     618     obs, rews, dones, infos = zip(*results)
#
# File ~\Desktop\assignment4\core\envs.py:616, in <listcomp>(.0)
#     615 def step_wait(self):
# --> 616     results = [remote.recv() for remote in self.remotes]
#     617     self.waiting = False
#     618     obs, rews, dones, infos = zip(*results)
#
# File c:\Users\blerd\anaconda3\envs\cs260r\Lib\multiprocessing\connection.py:249, in _ConnectionBase.recv(self)
#     247 self._check_closed()
#     248 self._check_readable()
# --> 249 buf = self._recv_bytes()
#     250 return _ForkingPickler.loads(buf.getbuffer())
#
# File c:\Users\blerd\anaconda3\envs\cs260r\Lib\multiprocessing\connection.py:320, in PipeConnection._recv_bytes(self, maxsize)
#     318 except OSError as e:
#     319     if e.winerror == _winapi.ERROR_BROKEN_PIPE:
# --> 320         raise EOFError
#     321     else:
#     322         raise
#
# EOFError:
